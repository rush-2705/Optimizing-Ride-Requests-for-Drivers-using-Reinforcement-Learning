# %%
import numpy as np
import pandas as pd
import random
from collections import defaultdict
from algorithms import sarsa,exp_sarsa,nstep_sarsa,q_learning
import sys
import tqdm
import matplotlib.pyplot as plt
from itertools import permutations
import gym
from gym import spaces

# %%
class TaxiData:
    def __init__(self):
        self.filepath = "final_updated_norm.csv"
        self.df, self.db_len = self.load_data()
        self.search_window = 10
        self.current_time = 0
        self.delay_time = 15
        self.current_zone = 3
        self.current_day = 0
        self.penalty = 0.25

    def load_data(self):
        df = pd.read_csv(self.filepath)
        df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
        df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])
        df['pickup_time'] = df['tpep_pickup_datetime'].dt.hour * 60 + df['tpep_pickup_datetime'].dt.minute
        df['pickup_day'] = df['tpep_pickup_datetime'].dt.day_name()
        df['dropoff_time'] = df['tpep_dropoff_datetime'].dt.hour * 60 + df['tpep_dropoff_datetime'].dt.minute
        df['dropoff_day'] = df['tpep_dropoff_datetime'].dt.day_name()
        df['pickup_zone'] = df['PULocationID']
        df['dropoff_zone'] = df['DOLocationID']
        df['fare'] = df['fare']
        df['trip_distance'] = df['trip_distance']
        return df , len(pd.read_csv(self.filepath))


    def day_to_number(self,day_name):
        # Dictionary mapping day names to day numbers
        day_dict = {
            "Monday": 0,
            "Tuesday": 1,
            "Wednesday": 2,
            "Thursday": 3,
            "Friday": 4,
            "Saturday": 5,
            "Sunday": 6
        }

        # Convert the day name to title case to handle mixed case inputs
        day_name = day_name.title()

        # Return the day number or raise an error if the day name is invalid
        if day_name in day_dict:
            return day_dict[day_name]
        else:
            raise ValueError("Invalid day name. Please enter a valid day of the week.")

    def get_value_by_index(self, index, column_name):
        """Retrieve a specific value from a DataFrame based on an index and column name."""
        try:
            return self.df.at[index, column_name]
        except KeyError:
            print(f"Column {column_name} does not exist in the DataFrame.")
            return None
        except IndexError:
            print(f"Index {index} is out of bounds for the DataFrame.")
            return None


    def wait_action(self):
        self.current_time += self.delay_time
        self.fare = 0
        return self.current_zone, self.current_time, self.fare, self.current_day

    #zone,minute_of_day, day_name
    def take_action_1(self,zone,minute_of_day, day_of_week, num_trips):
        """
        Find the indices of the next 'num_trips' trips for a given minute of day and day of week.
        """
        # Filter the DataFrame to find entries that match the time and day criteria
    #     potential_trips = self.df[
    #     (self.df['pickup_time'] > minute_of_day) & (self.df['pickup_time'] < minute_of_day + self.search_window) &
    #     (self.df['pickup_day'] == day_of_week) & (self.df['pickup_zone'] == zone)
    # ]
        potential_trips = self.df[
            (self.df['pickup_time'] > minute_of_day+self.search_window) & 
            (self.df['pickup_day'] == day_of_week) & (self.df['pickup_zone'] == zone)
    ]

        # print(potential_trips)

        # Check if the filtered DataFrame has enough entries
        # if not filtered_df.empty:
        #     if len(filtered_df) >= num_trips:
        #         return filtered_df.iloc[:num_trips].index.tolist()
        #     else:
        #         print("Not enough trips meet the criteria. Returning available trips.")
        #         return filtered_df.index.tolist()
        # else:
        #     return []  # Return an empty list if no trips are found
        
        if potential_trips.empty:
            # No trips available, taxi waits
            print("empty list current zone {}".format(self.current_zone))
            self.current_time += self.search_window
            self.fare = 0
        else:
            # Take the trip with the minimum pickup time
            selected_trip = potential_trips.nsmallest(1, 'pickup_time').iloc[0]
            # self.current_location = selected_trip['dropoff_location']
            self.current_zone = selected_trip['dropoff_zone']
            self.current_time = selected_trip['dropoff_time']
            self.current_day = selected_trip['dropoff_day']
            self.fare = selected_trip['fare']
            self.current_day = self.day_to_number(self.current_day)
            print("list current zone {}".format(self.current_zone))


        # print(self.current_zone, self.current_time, self.fare, self.current_day)
        return self.current_zone, self.current_time, self.fare, self.current_day
    
    def take_action_2(self,zone,minute_of_day, day_of_week):
        self.current_zone = zone
        self.current_time = minute_of_day+15
        self.current_day = day_of_week
        self.current_day = self.day_to_number(self.current_day)
        self.fare = 0
        print("action 2 current zone {}".format(self.current_zone))
        return self.current_zone, self.current_time, self.fare, self.current_day

# %%
class CabEnvironment(gym.Env):
    def __init__(self):
        super(CabEnvironment, self).__init__()

        self.max_zones = 200
        self.max_minutes = 1440  # Number of minutes in a day

        # penalty to switch to different zone
        self.penalty = 0.25

        # Define action and observation space
        # They must be gym.spaces objects
        #action,zone
        # self.action_space = spaces.Discrete(2)  # Two actions: wait or go
        self.action_space = [(action_type,zone) for zone in range(1,self.max_zones+1) for action_type in [1, 2]] + [(0,0)] 
        self.observation_space = spaces.Tuple((
            spaces.Discrete(self.max_zones + 1),
            spaces.Discrete(self.max_minutes + 1),
            spaces.Discrete(7)
        ))

        self.state_space = [[zone, minute_of_day, day_of_the_week] for zone in range(1,self.max_zones+1) for minute_of_day in range(self.max_minutes+1) for day_of_the_week in range(7)]
        self.state = None
        self.taxiRequest = TaxiData()

    def reset(self):
        self.state = [random.randint(1, self.max_zones), random.randint(0, 420), random.randint(0, 6)]
        # print("reset state",self.state[0])
        return self.state

    def step(self, action):
        reward = 0
        done = False
        zone = action[1]
        # Wait action adds 15 mins
        # print("action",action)
        if action[0] == 0:
            print("action zero")
            next_state = [self.state[0],self.state[1]+15,self.state[2]]


        # Driver decides to go to the next request, gets rewards
        elif action[0]== 1 :
            #zone minute day
            # drop_zone,fare,drop_time,drop_day = self.getNextRequest(self.state[0],self.state[1],self.state[2])
            #zone
            #print(action)
            #print(action[1])
            #print("zone {} ".format(zone))
            drop_zone,fare,drop_time,drop_day = self.getNextRequest(zone,self.state[1],self.state[2],action[0])
            print("drop zone {} ".format(drop_zone))
            
            if drop_zone == self.state[0]:
                reward = fare
            else:
                reward = fare - self.penalty
            next_state = [drop_zone,drop_time,drop_day]

        elif action[0]==2:
            drop_zone,fare,drop_time,drop_day = self.getNextRequest(zone,self.state[1],self.state[2],action[0])
            zone =action[1]
            print("drop zone {} ".format(zone))
            reward = -1*self.penalty
            next_state = [drop_zone,drop_time,drop_day]

            
        # if minutes are greater than 1440 then go to the next day
        if next_state[1]>=1440:
            next_state[1]=next_state[1]-1440
            next_state[2]=next_state[2]+1

            #if it goes to next day then done is true
            #done = True

            # print("next day")
            
        # # checks if the week is over to end the episode
        if next_state[2] == 6:
            done = True

        # print("next state",next_state)    
        self.state = next_state
        print("reward",reward)
        return next_state, reward, done, 1
    
    def reverse(self,day):
        
        
        day_number ={0: 'Monday', 
             1: 'Tuesday', 
             2: 'Wednesday', 
             3: 'Thursday', 
             4: 'Friday', 
             5: 'Saturday', 
             6: 'Sunday'}
        return day_number[day]
    

    def render(self, mode='human'):
        # Optional: Implement this if you want to visualize the environment
        pass

    def getNextRequest(self,zone,minute_of_day,day,action):
        
        day_name = self.reverse(day)
        # print(day_name)
        if action == 1:
            drop_zone, drop_time, fare, drop_day = self.taxiRequest.take_action_1(zone,minute_of_day, day_name, 1)

        elif action ==2:
            drop_zone, drop_time, fare, drop_day = self.taxiRequest.take_action_2(zone,minute_of_day, day_name)
        

        return drop_zone,fare,drop_time, drop_day

# %%
env = CabEnvironment()

# %%
num_trials = 1

# pbar = tqdm.trange(num_trials)
for i in range(num_trials):
    Q_sarsa, reward = sarsa(env, num_steps=500, gamma=1, epsilon=0.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 Q_sarsa, history = sarsa(env, num_steps=8000, gamma=1, epsilon=0.1)
#
# File ~/Desktop/NEU/RL/project/code/algorithms.py:67, in sarsa(env, num_steps, gamma, epsilon)
#      65 state = env.reset()
#      66 policy = create_epsilon_policy(Q,epsilon)
# ---> 67 action = policy(state)
#      68 rewards = 0
#      69 done = False
#
# File ~/Desktop/NEU/RL/project/code/algorithms.py:42, in create_epsilon_policy.<locals>.get_action(state)
#      40     action = np.random.randint(num_actions)
#      41 else:
# ---> 42     action = argmax(Q[state])
#      44 return action
#
# TypeError: unhashable type: 'list'

# %%
def map_minute_to_time_of_day(minute):
  
    time_of_day_duration = 360  
    
    time_of_day_index = minute // time_of_day_duration
    
    return time_of_day_index

# Test the function

    
time_of_day = map_minute_to_time_of_day(1080)
print(time_of_day)
# Out:
# 3

# %%
class CabEnvironment(gym.Env):
    def __init__(self):
        super(CabEnvironment, self).__init__()

        self.max_zones = 200
        self.max_times = 4  # Number of minutes in a day
        self.minute_of_the_day = 0

        # penalty to switch to different zone
        self.penalty = 0.15

        # Define action and observation space
        # They must be gym.spaces objects
        #action,zone
        # self.action_space = spaces.Discrete(2)  # Two actions: wait or go
        self.action_space = [(action_type,zone) for zone in range(1,self.max_zones+1) for action_type in [1, 2]] + [(0,0)] 
        self.observation_space = spaces.Tuple((
            spaces.Discrete(self.max_zones + 1),
            spaces.Discrete(self.max_times + 1),
            spaces.Discrete(7)
        ))

        self.state_space = [[zone, time_zone, day_of_the_week] for zone in range(1,self.max_zones+1) for time_zone in range(self.max_times+1) for day_of_the_week in range(7)]
        self.state = None
        self.taxiRequest = TaxiData()

    def reset(self):
        self.minute_of_the_day = random.randint(0, 420)
        time_zone = self.change_minute_to_time(self.minute_of_the_day)
        self.state = [random.randint(1, self.max_zones),time_zone , random.randint(0, 6)]
        return self.state

    def step(self, action):
        reward = 0
        done = False
        zone = action[1]
        # Wait action adds 15 mins
        # print("action",action)
        if action[0] == 0:
            print("action zero")
            self.minute_of_the_day=+15
            time_zone = self.change_minute_to_time(self.minute_of_the_day)
            next_state = [self.state[0],time_zone,self.state[2]]


        # Driver decides to go to the next request, gets rewards
        elif action[0]== 1 :
            #zone minute day
            
            drop_zone,fare,drop_time,drop_day = self.getNextRequest(zone,self.minute_of_the_day,self.state[2],action[0])
            print("pick up zone {} drop zone {} action {}".format(zone,drop_zone,action[0]))
            
            print("fare", fare)
            if drop_zone == self.state[0]:
                reward = fare
            else:
                reward = fare - self.penalty
            self.minute_of_the_day = drop_time    
            drop_time_zone = self.change_minute_to_time(self.minute_of_the_day)
            next_state = [drop_zone,drop_time_zone,drop_day]

        elif action[0]==2:
            drop_zone,fare,drop_time,drop_day = self.getNextRequest(zone,self.minute_of_the_day,self.state[2],action[0])
            zone =action[1]
            print("pick up zone {} drop zone {} action {}".format(zone,drop_zone,action[0]))
            reward = -1*self.penalty
            self.minute_of_the_day = drop_time    
            drop_time_zone = self.change_minute_to_time(self.minute_of_the_day)
            next_state = [drop_zone,drop_time_zone,drop_day]

            
        # if minutes are greater than 1440 then go to the next day
        if self.minute_of_the_day>=1440:
            self.minute_of_the_day=self.minute_of_the_day-1440
            next_state[1] = 0
            next_state[2]=next_state[2]+1

            #if it goes to next day then done is true
            #done = True

            # print("next day")
            
        # # checks if the week is over to end the episode
        if next_state[2] == 6:
            done = True

        # print("next state",next_state)    
        self.state = next_state
        print("reward",reward)
        return next_state, reward, done, 1
    
    def reverse(self,day):
        
        
        day_number ={0: 'Monday', 
             1: 'Tuesday', 
             2: 'Wednesday', 
             3: 'Thursday', 
             4: 'Friday', 
             5: 'Saturday', 
             6: 'Sunday'}
        return day_number[day]
    

    def render(self, mode='human'):
        # Optional: Implement this if you want to visualize the environment
        pass

    def getNextRequest(self,zone,minute_of_day,day,action):
        
        day_name = self.reverse(day)
        # print(day_name)
        if action == 1:
            drop_zone, drop_time, fare, drop_day = self.taxiRequest.take_action_1(zone,minute_of_day, day_name, 1)

        elif action ==2:
            drop_zone, drop_time, fare, drop_day = self.taxiRequest.take_action_2(zone,minute_of_day, day_name)
        

        return drop_zone,fare,drop_time, drop_day
    
    
    def change_minute_to_time(self,minute):
        time_of_day_duration = 360  
        time_of_day_index = minute // time_of_day_duration
        
        return time_of_day_index

# %%
env = CabEnvironment()

# %%
def test_environment(env):
    observation = env.reset()
    done = False
    step_index = 0

    while not done and step_index < 100:
        
        action = random.choice(env.action_space)
        # print(action) # Randomly sample an action
       
        observation, reward, done, _ = env.step(action)
        print(f"Step {step_index}: Action={action}, Observation={observation}, Reward={reward}")
        step_index += 1

    env.close()

# %%
test_environment(env)
# Out:
# list current zone 41
# pick up zone 41 drop zone 41 action 1
# fare 0.1545084745762711
# reward 0.004508474576271099
# Step 0: Action=(1, 41), Observation=[41, 0, 3], Reward=0.004508474576271099
# action 2 current zone 97
# pick up zone 97 drop zone 97 action 2
# reward -0.15
# Step 1: Action=(2, 97), Observation=[97, 0, 3], Reward=-0.15
# list current zone 168
# pick up zone 72 drop zone 168 action 1
# fare 0.161864406779661
# reward 0.011864406779660996
# Step 2: Action=(1, 72), Observation=[168, 0, 3], Reward=0.011864406779660996
# list current zone 68
# pick up zone 149 drop zone 68 action 1
# fare 0.1594915254237288
# reward 0.009491525423728803
# Step 3: Action=(1, 149), Observation=[68, 1, 3], Reward=0.009491525423728803
# list current zone 205
# pick up zone 26 drop zone 205 action 1
# fare 0.1640677966101695
# reward 0.014067796610169492
# Step 4: Action=(1, 26), Observation=[205, 1, 3], Reward=0.014067796610169492
# list current zone 252
# pick up zone 92 drop zone 252 action 1
# fare 0.1557627118644067
# reward 0.005762711864406717
# Step 5: Action=(1, 92), Observation=[252, 1, 3], Reward=0.005762711864406717
# action 2 current zone 15
# pick up zone 15 drop zone 15 action 2
# reward -0.15
# Step 6: Action=(2, 15), Observation=[15, 1, 3], Reward=-0.15
# action 2 current zone 157
# pick up zone 157 drop zone 157 action 2
# reward -0.15
# Step 7: Action=(2, 157), Observation=[157, 1, 3], Reward=-0.15
# list current zone 230
# pick up zone 13 drop zone 230 action 1
# fare 0.1574067796610169
# reward 0.00740677966101691
# Step 8: Action=(1, 13), Observation=[230, 1, 3], Reward=0.00740677966101691
# list current zone 265
# pick up zone 129 drop zone 265 action 1
# fare 0.1846661016949152
# reward 0.03466610169491521
# Step 9: Action=(1, 129), Observation=[265, 2, 3], Reward=0.03466610169491521
# action 2 current zone 92
# pick up zone 92 drop zone 92 action 2
# reward -0.15
# Step 10: Action=(2, 92), Observation=[92, 2, 3], Reward=-0.15
# action 2 current zone 14
# pick up zone 14 drop zone 14 action 2
# reward -0.15
# Step 11: Action=(2, 14), Observation=[14, 2, 3], Reward=-0.15
# action 2 current zone 191
# pick up zone 191 drop zone 191 action 2
# reward -0.15
# Step 12: Action=(2, 191), Observation=[191, 2, 3], Reward=-0.15
# action 2 current zone 89
# pick up zone 89 drop zone 89 action 2
# reward -0.15
# Step 13: Action=(2, 89), Observation=[89, 2, 3], Reward=-0.15
# list current zone 75
# pick up zone 140 drop zone 75 action 1
# fare 0.1562440677966101
# reward 0.006244067796610103
# Step 14: Action=(1, 140), Observation=[75, 2, 3], Reward=0.006244067796610103
# action 2 current zone 98
# pick up zone 98 drop zone 98 action 2
# reward -0.15
# Step 15: Action=(2, 98), Observation=[98, 2, 3], Reward=-0.15
# action 2 current zone 37
# pick up zone 37 drop zone 37 action 2
# reward -0.15
# Step 16: Action=(2, 37), Observation=[37, 2, 3], Reward=-0.15
# action 2 current zone 96
# pick up zone 96 drop zone 96 action 2
# reward -0.15
# Step 17: Action=(2, 96), Observation=[96, 2, 3], Reward=-0.15
# action 2 current zone 103
# pick up zone 103 drop zone 103 action 2
# reward -0.15
# Step 18: Action=(2, 103), Observation=[103, 2, 3], Reward=-0.15
# action 2 current zone 19
# pick up zone 19 drop zone 19 action 2
# reward -0.15
# Step 19: Action=(2, 19), Observation=[19, 2, 3], Reward=-0.15
# action 2 current zone 171
# pick up zone 171 drop zone 171 action 2
# reward -0.15
# Step 20: Action=(2, 171), Observation=[171, 2, 3], Reward=-0.15
# list current zone 75
# pick up zone 182 drop zone 75 action 1
# fare 0.1591423728813559
# reward 0.009142372881355915
# Step 21: Action=(1, 182), Observation=[75, 3, 3], Reward=0.009142372881355915
# empty list current zone 75
# pick up zone 84 drop zone 75 action 1
# fare 0
# reward 0
# Step 22: Action=(1, 84), Observation=[75, 3, 3], Reward=0
# list current zone 160
# pick up zone 160 drop zone 160 action 1
# fare 0.1555084745762711
# reward 0.0055084745762711
# Step 23: Action=(1, 160), Observation=[160, 3, 3], Reward=0.0055084745762711
# empty list current zone 160
# pick up zone 69 drop zone 160 action 1
# fare 0
# reward 0
# Step 24: Action=(1, 69), Observation=[160, 3, 3], Reward=0
# action 2 current zone 55
# pick up zone 55 drop zone 55 action 2
# reward -0.15
# Step 25: Action=(2, 55), Observation=[55, 3, 3], Reward=-0.15
# action 2 current zone 63
# pick up zone 63 drop zone 63 action 2
# reward -0.15
# Step 26: Action=(2, 63), Observation=[63, 3, 3], Reward=-0.15
# action 2 current zone 65
# pick up zone 65 drop zone 65 action 2
# reward -0.15
# Step 27: Action=(2, 65), Observation=[65, 0, 4], Reward=-0.15
# action 2 current zone 184
# pick up zone 184 drop zone 184 action 2
# reward -0.15
# Step 28: Action=(2, 184), Observation=[184, 0, 4], Reward=-0.15
# action 2 current zone 29
# pick up zone 29 drop zone 29 action 2
# reward -0.15
# Step 29: Action=(2, 29), Observation=[29, 0, 4], Reward=-0.15
# action 2 current zone 155
# pick up zone 155 drop zone 155 action 2
# reward -0.15
# Step 30: Action=(2, 155), Observation=[155, 0, 4], Reward=-0.15
# list current zone 227
# pick up zone 123 drop zone 227 action 1
# fare 0.1566101694915254
# reward 0.006610169491525403
# Step 31: Action=(1, 123), Observation=[227, 0, 4], Reward=0.006610169491525403
# empty list current zone 227
# pick up zone 103 drop zone 227 action 1
# fare 0
# reward 0
# Step 32: Action=(1, 103), Observation=[227, 0, 4], Reward=0
# list current zone 210
# pick up zone 86 drop zone 210 action 1
# fare 0.1633898305084745
# reward 0.013389830508474504
# Step 33: Action=(1, 86), Observation=[210, 1, 4], Reward=0.013389830508474504
# action 2 current zone 168
# pick up zone 168 drop zone 168 action 2
# reward -0.15
# Step 34: Action=(2, 168), Observation=[168, 1, 4], Reward=-0.15
# action 2 current zone 68
# pick up zone 68 drop zone 68 action 2
# reward -0.15
# Step 35: Action=(2, 68), Observation=[68, 1, 4], Reward=-0.15
# list current zone 141
# pick up zone 55 drop zone 141 action 1
# fare 0.1620338983050847
# reward 0.012033898305084695
# Step 36: Action=(1, 55), Observation=[141, 1, 4], Reward=0.012033898305084695
# list current zone 191
# pick up zone 16 drop zone 191 action 1
# fare 0.1569491525423728
# reward 0.0069491525423727996
# Step 37: Action=(1, 16), Observation=[191, 1, 4], Reward=0.0069491525423727996
# list current zone 73
# pick up zone 73 drop zone 73 action 1
# fare 0.1633898305084745
# reward 0.013389830508474504
# Step 38: Action=(1, 73), Observation=[73, 2, 4], Reward=0.013389830508474504
# action 2 current zone 156
# pick up zone 156 drop zone 156 action 2
# reward -0.15
# Step 39: Action=(2, 156), Observation=[156, 2, 4], Reward=-0.15
# action 2 current zone 141
# pick up zone 141 drop zone 141 action 2
# reward -0.15
# Step 40: Action=(2, 141), Observation=[141, 2, 4], Reward=-0.15
# action 2 current zone 71
# pick up zone 71 drop zone 71 action 2
# reward -0.15
# Step 41: Action=(2, 71), Observation=[71, 2, 4], Reward=-0.15
# list current zone 36
# pick up zone 92 drop zone 36 action 1
# fare 0.1584745762711864
# reward 0.008474576271186418
# Step 42: Action=(1, 92), Observation=[36, 2, 4], Reward=0.008474576271186418
# list current zone 157
# pick up zone 98 drop zone 157 action 1
# fare 0.1609661016949152
# reward 0.010966101694915215
# Step 43: Action=(1, 98), Observation=[157, 3, 4], Reward=0.010966101694915215
# action 2 current zone 23
# pick up zone 23 drop zone 23 action 2
# reward -0.15
# Step 44: Action=(2, 23), Observation=[23, 3, 4], Reward=-0.15
# empty list current zone 23
# pick up zone 135 drop zone 23 action 1
# fare 0
# reward 0
# Step 45: Action=(1, 135), Observation=[23, 3, 4], Reward=0
# empty list current zone 23
# pick up zone 58 drop zone 23 action 1
# fare 0
# reward 0
# Step 46: Action=(1, 58), Observation=[23, 3, 4], Reward=0
# empty list current zone 23
# pick up zone 135 drop zone 23 action 1
# fare 0
# reward 0
# Step 47: Action=(1, 135), Observation=[23, 3, 4], Reward=0
# list current zone 76
# pick up zone 17 drop zone 76 action 1
# fare 0.1567796610169491
# reward 0.006779661016949101
# Step 48: Action=(1, 17), Observation=[76, 3, 4], Reward=0.006779661016949101
# empty list current zone 76
# pick up zone 20 drop zone 76 action 1
# fare 0
# reward 0
# Step 49: Action=(1, 20), Observation=[76, 3, 4], Reward=0
# empty list current zone 76
# pick up zone 185 drop zone 76 action 1
# fare 0
# reward 0
# Step 50: Action=(1, 185), Observation=[76, 3, 4], Reward=0
# empty list current zone 76
# pick up zone 175 drop zone 76 action 1
# fare 0
# reward 0
# Step 51: Action=(1, 175), Observation=[76, 3, 4], Reward=0
# action 2 current zone 105
# pick up zone 105 drop zone 105 action 2
# reward -0.15
# Step 52: Action=(2, 105), Observation=[105, 3, 4], Reward=-0.15
# action 2 current zone 38
# pick up zone 38 drop zone 38 action 2
# reward -0.15
# Step 53: Action=(2, 38), Observation=[38, 3, 4], Reward=-0.15
# list current zone 132
# pick up zone 177 drop zone 132 action 1
# fare 0.1592881355932203
# reward 0.009288135593220309
# Step 54: Action=(1, 177), Observation=[132, 3, 4], Reward=0.009288135593220309
# action 2 current zone 26
# pick up zone 26 drop zone 26 action 2
# reward -0.15
# Step 55: Action=(2, 26), Observation=[26, 3, 4], Reward=-0.15
# empty list current zone 26
# pick up zone 27 drop zone 26 action 1
# fare 0
# reward 0
# Step 56: Action=(1, 27), Observation=[26, 3, 4], Reward=0
# empty list current zone 26
# pick up zone 121 drop zone 26 action 1
# fare 0
# reward 0
# Step 57: Action=(1, 121), Observation=[26, 3, 4], Reward=0
# action 2 current zone 157
# pick up zone 157 drop zone 157 action 2
# reward -0.15
# Step 58: Action=(2, 157), Observation=[157, 3, 4], Reward=-0.15
# list current zone 24
# pick up zone 100 drop zone 24 action 1
# fare 0.1574440677966101
# reward 0.00744406779661011
# Step 59: Action=(1, 100), Observation=[24, 3, 4], Reward=0.00744406779661011
# action 2 current zone 110
# pick up zone 110 drop zone 110 action 2
# reward -0.15
# Step 60: Action=(2, 110), Observation=[110, 3, 4], Reward=-0.15
# empty list current zone 110
# pick up zone 4 drop zone 110 action 1
# fare 0
# reward 0
# Step 61: Action=(1, 4), Observation=[110, 0, 5], Reward=0
# action 2 current zone 131
# pick up zone 131 drop zone 131 action 2
# reward -0.15
# Step 62: Action=(2, 131), Observation=[131, 0, 5], Reward=-0.15
# list current zone 265
# pick up zone 19 drop zone 265 action 1
# fare 0.1669491525423729
# reward 0.01694915254237289
# Step 63: Action=(1, 19), Observation=[265, 1, 5], Reward=0.01694915254237289
# list current zone 42
# pick up zone 18 drop zone 42 action 1
# fare 0.1572881355932203
# reward 0.007288135593220307
# Step 64: Action=(1, 18), Observation=[42, 1, 5], Reward=0.007288135593220307
# action 2 current zone 142
# pick up zone 142 drop zone 142 action 2
# reward -0.15
# Step 65: Action=(2, 142), Observation=[142, 1, 5], Reward=-0.15
# list current zone 140
# pick up zone 150 drop zone 140 action 1
# fare 0.1638033898305085
# reward 0.013803389830508495
# Step 66: Action=(1, 150), Observation=[140, 2, 5], Reward=0.013803389830508495
# list current zone 114
# pick up zone 113 drop zone 114 action 1
# fare 0.1546779661016949
# reward 0.004677966101694908
# Step 67: Action=(1, 113), Observation=[114, 2, 5], Reward=0.004677966101694908
# action 2 current zone 69
# pick up zone 69 drop zone 69 action 2
# reward -0.15
# Step 68: Action=(2, 69), Observation=[69, 2, 5], Reward=-0.15
# action 2 current zone 79
# pick up zone 79 drop zone 79 action 2
# reward -0.15
# Step 69: Action=(2, 79), Observation=[79, 2, 5], Reward=-0.15
# action 2 current zone 21
# pick up zone 21 drop zone 21 action 2
# reward -0.15
# Step 70: Action=(2, 21), Observation=[21, 2, 5], Reward=-0.15
# action 2 current zone 74
# pick up zone 74 drop zone 74 action 2
# reward -0.15
# Step 71: Action=(2, 74), Observation=[74, 2, 5], Reward=-0.15
# action 2 current zone 54
# pick up zone 54 drop zone 54 action 2
# reward -0.15
# Step 72: Action=(2, 54), Observation=[54, 2, 5], Reward=-0.15
# action 2 current zone 57
# pick up zone 57 drop zone 57 action 2
# reward -0.15
# Step 73: Action=(2, 57), Observation=[57, 2, 5], Reward=-0.15
# action 2 current zone 23
# pick up zone 23 drop zone 23 action 2
# reward -0.15
# Step 74: Action=(2, 23), Observation=[23, 2, 5], Reward=-0.15
# list current zone 14
# pick up zone 127 drop zone 14 action 1
# fare 0.1623728813559322
# reward 0.012372881355932203
# Step 75: Action=(1, 127), Observation=[14, 2, 5], Reward=0.012372881355932203
# action 2 current zone 26
# pick up zone 26 drop zone 26 action 2
# reward -0.15
# Step 76: Action=(2, 26), Observation=[26, 2, 5], Reward=-0.15
# list current zone 132
# pick up zone 139 drop zone 132 action 1
# fare 0.1575423728813559
# reward 0.0075423728813558966
# Step 77: Action=(1, 139), Observation=[132, 3, 5], Reward=0.0075423728813558966
# empty list current zone 132
# pick up zone 35 drop zone 132 action 1
# fare 0
# reward 0
# Step 78: Action=(1, 35), Observation=[132, 3, 5], Reward=0
# list current zone 238
# pick up zone 143 drop zone 238 action 1
# fare 0.1554508474576271
# reward 0.0054508474576271115
# Step 79: Action=(1, 143), Observation=[238, 3, 5], Reward=0.0054508474576271115
# action 2 current zone 122
# pick up zone 122 drop zone 122 action 2
# reward -0.15
# Step 80: Action=(2, 122), Observation=[122, 3, 5], Reward=-0.15
# action 2 current zone 187
# pick up zone 187 drop zone 187 action 2
# reward -0.15
# Step 81: Action=(2, 187), Observation=[187, 3, 5], Reward=-0.15
# action 2 current zone 116
# pick up zone 116 drop zone 116 action 2
# reward -0.15
# Step 82: Action=(2, 116), Observation=[116, 3, 5], Reward=-0.15
# action 2 current zone 138
# pick up zone 138 drop zone 138 action 2
# reward -0.15
# Step 83: Action=(2, 138), Observation=[138, 3, 5], Reward=-0.15
# empty list current zone 138
# pick up zone 160 drop zone 138 action 1
# fare 0
# reward 0
# Step 84: Action=(1, 160), Observation=[138, 3, 5], Reward=0
# empty list current zone 138
# pick up zone 22 drop zone 138 action 1
# fare 0
# reward 0
# Step 85: Action=(1, 22), Observation=[138, 3, 5], Reward=0
# action 2 current zone 88
# pick up zone 88 drop zone 88 action 2
# reward -0.15
# Step 86: Action=(2, 88), Observation=[88, 3, 5], Reward=-0.15
# empty list current zone 88
# pick up zone 54 drop zone 88 action 1
# fare 0
# reward 0
# Step 87: Action=(1, 54), Observation=[88, 0, 6], Reward=0
